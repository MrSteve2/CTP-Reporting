# %%
#hide
import pandas as pd
import urllib3 as urllib
import json
import math
from datetime import datetime
from IPython.core.display import HTML

import IPython.display
import altair as alt

pd.options.display.max_columns = None # Used when you have a lot of columns and want them all 'displayed'

# %%
# %%time
print ('Please be patient loading the CMS data can take a bit over 1 minute')
url = 'https://data.cms.gov/api/views/s2uc-8wxp/rows.csv?accessType=DOWNLOAD'

#url = 'https://healthdata.gov/node/3762431/download'
# df = pd.read_csv('C:/Users/MrSteve/Downloads/COVID-19_Nursing_Home_Dataset (2).tsv',  sep='\t', parse_dates=['Week Ending'])
# df = pd.read_csv(url,  sep='\t', parse_dates=['Week Ending'])

df_cms = pd.read_csv(url, parse_dates=['Week Ending'], low_memory=False)

df_cms_latest = df_cms[df_cms['Week Ending'] == max(df_cms['Week Ending'].unique())]
# Out:
# Please be patient loading the CMS data can take a bit over 1 minute
# Wall time: 1min 10s

# %%
state= 'IL'
il_cms_df = df_cms[df_cms['Provider State'] == state]
# df_cms.columns

# %%
il_data_df = pd.read_json('https://api.covidtracking.com/v1/states/il/daily.json')
il_data_df['date']= pd.to_datetime(il_data_df['date'].astype(str), format='%Y%m%d')

# %%
il_cms_df.tail()
# Out:
#        Week Ending Federal Provider Number                   Provider Name  \
# 140260  2020-08-23                  14E888      SHARON HEALTH CARE WILLOWS
# 140262  2020-07-12                  14E848  DECATUR REHAB & HEALTH CARE CT
# 140270  2020-11-15                  14E701                     BIG MEADOWS
# 140278  2020-05-31                  14E361      ASPEN REHAB &  HEALTH CARE
# 140288  2020-08-23                  14E306        NORTH AURORA CARE CENTER
#
#              Provider Address Provider City Provider State  Provider Zip Code  \
# 140260    3520 NORTH ROCHELLE        PEORIA             IL              61604
# 140262  136 SOUTH DIPPER LANE       DECATUR             IL              62522
# 140270          1000 LONGMOOR       SAVANNA             IL              61074
# 140278        1403 9TH AVENUE        SILVIS             IL              61282
# 140288       310 BANBURY ROAD  NORTH AURORA             IL              60542
#
# ...

# %% [markdown]
# # PLAY AREA

# %%
df_agg = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRa9HnmEl83YXHfbgSPpt0fJe4SyuYLc0GuBAglF4yMYaoKSPRCyXASaWXMrTu1WEYp1oeJZIYHpj7t/pub?gid=827060758&single=true&output=csv')

# %%
df_cum = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRa9HnmEl83YXHfbgSPpt0fJe4SyuYLc0GuBAglF4yMYaoKSPRCyXASaWXMrTu1WEYp1oeJZIYHpj7t/pub?gid=467018747&single=true&output=csv')

# %%
df_current = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRa9HnmEl83YXHfbgSPpt0fJe4SyuYLc0GuBAglF4yMYaoKSPRCyXASaWXMrTu1WEYp1oeJZIYHpj7t/pub?gid=467018747&single=true&output=csv')

# %%
df_current.head()
# Out:
#   Cumulative Dataset Unnamed: 1       Released:    20210128  \
# 0               Date      State  Data Timestamp    Data Set
# 1           20200521         AK             NaN  Cumulative
# 2           20200528         AK             NaN  Cumulative
# 3           20200604         AK             NaN  Cumulative
# 4           20200611         AK             NaN  Cumulative
#
#         Nursing Homes                   Unnamed: 5       Unnamed: 6  \
# 0  Resident Positives  Probable Resident Positives  Resident Deaths
# 1                 NaN                          NaN              NaN
# 2                 NaN                          NaN              NaN
# 3                 NaN                          NaN              NaN
# 4                 NaN                          NaN              NaN
#
#                  Unnamed: 7       Unnamed: 8                Unnamed: 9  \
# 0  Probable Resident Deaths  Staff Positives  Probable Staff Positives
# ...

# %%
df_current.columns
# Out:
# Index(['Cumulative Dataset', 'Unnamed: 1', 'Released:', '20210128',
#        'Nursing Homes', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Assisted Living', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Long Term Care Facilities', 'Unnamed: 31',
#        'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35',
#        'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
#        'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Other', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
#        'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56',
# ...

# %%
df_agg.tail()
# Out:
#      Aggregate Dataset Released:  Unnamed: 2   20210128 Nursing Homes  \
# 2068          20210128        VT         NaN  Aggregate           NaN
# 2069          20210128        WA         NaN  Aggregate           NaN
# 2070          20210128        WI         NaN  Aggregate           NaN
# 2071          20210128        WV         NaN  Aggregate           NaN
# 2072          20210128        WY         NaN  Aggregate           969
#
#      Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 2068        NaN        NaN        NaN        NaN        NaN         NaN
# 2069        NaN        NaN        NaN        NaN        NaN         NaN
# 2070        NaN        NaN        NaN        NaN        NaN         NaN
# 2071        NaN        NaN        NaN        NaN        NaN         NaN
# 2072          9        136        NaN        809         48         NaN
#
#      Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# ...

# %%
state = 'IL'
state_df = df[df['Released:'] == state]

# %%
state_df
# Out:
#      Aggregate Dataset Released:  Unnamed: 2   20210128 Nursing Homes  \
# 17            20200521        IL         NaN  Aggregate           NaN
# 73            20200528        IL         NaN  Aggregate           NaN
# 129           20200604        IL         NaN  Aggregate           NaN
# 185           20200611        IL         NaN  Aggregate           NaN
# 241           20200618        IL         NaN  Aggregate           NaN
# 297           20200625        IL         NaN  Aggregate           NaN
# 353           20200702        IL         NaN  Aggregate           NaN
# 409           20200709        IL         NaN  Aggregate           NaN
# 465           20200716        IL         NaN  Aggregate           NaN
# 521           20200723        IL         NaN  Aggregate           NaN
# 577           20200730        IL         NaN  Aggregate           NaN
# 633           20200806        IL         NaN  Aggregate           NaN
# ...

# %%
df_il_fac=pd.read_csv('https://github.com/COVID19Tracking/long-term-care-data/blob/master/facilities_il.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-23-01c57d2b8909> in <module>
# ----> 1 df_il_fac=pd.read_csv('https://github.com/COVID19Tracking/long-term-care-data/blob/master/facilities_il.csv')
#
# ...

# %%
# df_il_fac=pd.read_csv('https://github.com/COVID19Tracking/long-term-care-data/blob/master/state_overview.csv')
df_il_ltc=pd.read_csv('https://raw.githubusercontent.com/COVID19Tracking/long-term-care-data/master/state_overview.csv')

# %%
df_il_ltc.tail()
# Out:
#           date  state  county  city  facility_name  facility_type_state  \
# 6213  20201231    NaN     NaN   NaN            NaN                  NaN
# 6214  20210107    NaN     NaN   NaN            NaN                  NaN
# 6215  20210114    NaN     NaN   NaN            NaN                  NaN
# 6216  20210121    NaN     NaN   NaN            NaN                  NaN
# 6217  20210128    NaN     NaN   NaN            NaN                  NaN
#
#       ctp_facility_category  state_fed_regulated  state_facility_id  \
# 6213                    NaN                  NaN                NaN
# 6214                    NaN                  NaN                NaN
# 6215                    NaN                  NaN                NaN
# 6216                    NaN                  NaN                NaN
# 6217                    NaN                  NaN                NaN
#
#       facility_cms_id  date_outbreak_opened  date_outreak_closed  \
# ...
